# %% [markdown]
# ### q) explain the classical exaples for right skewed and left skwed distributions and what are relation between mean, median, mode in right and left skewed distributions
#
# ### a)
#
#     1.1) for right skewed distribution the example can be wealth distribution, in this most popular people like elon musk, jeff basos and mark will fall in the skewed catagory
#     1.2) the comments distribution of a perticular video, the lenghty comments section falls under the right skeweness
#     2.1) for symmetrical or normal distribution, can say, age distribution, weight distribution
#     3.1) for the left skeweness, average life span distribution of a human being can be taken, most of people will die at age 70 to 80 very less will stay until 100 and deaths will be very low in between 0 to 50

# %% [markdown]
# ### for the secound part of the qution try to understand the below graphs

# %% [markdown]
# ![q1.PNG](attachment:q1.PNG)

# %% [markdown]
# here <br>
# mode = most common variable <br>
# median = is the middle point of the values <br>
# mean = the average of all values

# %% [markdown]
# # in right skewness the <b> Mode<Median<Mean </b>

# %% [markdown]
# # in the symmetriacl graph Mode=Median=Mean

# %% [markdown]
# # in the left skeweness Mean<Median<Mode
