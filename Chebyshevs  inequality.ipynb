# %% [markdown]
# #### if we consider the normal distribution it says that, as per how many standard deviations are considered accordingly the values belongs to the range
#
# #### it means, for the first standard deviation 68%
# #### secound standard deviation 95%
# #### third standard deviation 99.5%
#
# #### as per the normal distribution

# %% [markdown]
# ### if any random variable that does not follow gaussion distribution, it will be hard to get its standard deviation and range of data points how they belong
#
# ### Chebyshevs inequality says,
#
#
# #### consider k as the number of standard deviations
#
#
# # the probability of a random variable  falling within the range of  k standard deviation is always be grater than 1-1/k*k

# %% [markdown]
# ![cheb%20for.PNG](attachment:cheb%20for.PNG)

# %% [markdown]
# ####  here in left it shows the variable which follows the gaussian distribution, on the right it explains the chebyshevs formula for finding random variable which does not follow the normal distribution.
#
# #### here the formula is same for both for LHS, k is the number that written for number of standard deviation, on RHS the result will come accordingly
