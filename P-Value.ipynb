# %% [markdown]
# ### p- value is basically probablity value, where it used to observe that the, test results are atleast nearer to the results that are actually observed or not, by assuming the null hypothesis is true.
#
# ### here, generally in stats world, hypothesis is a saying by believing practically on something
# ###  -> like this medication may work on fever
# ###  -> this new teaching technique will work great in class etc...
#
# ### A hypothesis is an educated guess about something in the world around you. It should be testable, either by experiment or observation.

# %% [markdown]
# ### then there comes the hypothesis statement
# ### If you are going to propose a hypothesis, it’s customary to write a statement. Your statement will look like this:
# ### “If I…(do this to an independent variable)….then (this will happen to the dependent variable).”
#  For example:
#
# If I (decrease the amount of water given to herbs) then (the herbs will increase in size).
# If I (give patients counseling in addition to medication) then (their overall depression scale will decrease).
# If I (give exams at noon instead of 7) then (student test scores will improve).

# %% [markdown]
# ### hypothesis testing
#
# ### Hypothesis testing in statistics is a way for you to test the results of a survey or experiment to see if you have meaningful results. You’re basically testing whether your results are valid by figuring out the odds that your results have happened by chance. If your results may have happened by chance, the experiment won’t be repeatable and so has little use.
#
# ### this test basically tries to delete or explain the unrealistic possiblity like happening by luck possibilieties from the result
#
# ### for example if a drug is tested on 2 groups and one group is recovered so fast, it doesnt mean that the drug worked perfectly on that group maybe the group members have more immune gene compared to another group, here the collection of immune gene group is not our priority but it happened by chance, so before confirming that the drug is worked we needed to be confident that the results happened only happened because of the drugs, to help our confidence the statistical term which helps is p value.
#
# ### basically p value flaots between 0 and 1, where,

# %% [markdown]
# ### the null hypothesis
# ### If you trace back the history of science, the null hypothesis is always the accepted fact. Simple examples of null hypotheses that are generally accepted as being true are:
#
# DNA is shaped like a double helix.
# There are 8 planets in the solar system (excluding Pluto).
#
# ### basically for data analysts the domain heads willl give the null hypothesis point or it can be generally believed facts that can get from company
#
# like sales on increasing on the saturday (it is a saying in company but may not be true)

# %% [markdown]
# ### by testing the p value you can check that we can reject the null hypothesis or not, this is the main purpose of p value testing. also the significance value which is used to accept or reject the null hypothesis

# %% [markdown]
# ### for example
# ### consider coin toss experiment for 100 times
# ### my null hypothesis is it is a fair coin , which means it will give 50 heads and 50 tails (H0)
# ### alternate to the null hypothesis is the coin is not fair (H1)
# ### the significance value given is p=0.05 means in normal words 5 chances of missing accuracy

# %% [markdown]
# ![P%20value%20figure.PNG](attachment:P%20value%20figure.PNG)

# %% [markdown]
# ### if my experiment resulted in 53 heads it says the possiblility of null hypothesis is true
# ### or if my experiment end up giving me vlaues out of significance line like showned in the graph, it can be said that ( in professional languange maybe) the null hypothesis is rejected. simply it does not falls under the assumption ( hypothesis ) that we assumed about the coin.

# %% [markdown]
# ### the major thing about the experiments is those can be done repeatedly, so rejecting or declaring true depends on the possible situations at the time when the experiment is taking place
