# %% [markdown]
# ### by using the covarience we can only get the direction of the relation, wheather it is +ve or -ve.
# ### to know the strength of the relation pearson correlation coeffecient is used

# %% [markdown]
# ### it generally means, the value of the PCC comes between 1 and -1.
# ### if PCC comes 0 it means the variables are not at all corealted.
# ### basically it shows the percentage of  how much the variables are related.
# ### this PCC technique is widely used in feature selection process.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### the PCC is calculated by dividing the covarience by standard deviation of x and y

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### as per above graphs explained, PCC is a number between -1 and +1 to explain how much the 2 variables are related.

# %% [markdown]
# #### the summation value is 194 ,
