# %% [markdown]
# ### Feature scaling is one of the major processes in the world of machine learning
# ### where, standardisation and normalisation are used for
#
# ### these techniques are used, when the data is comparatively not distributed and also when having large number of values

# %% [markdown]
# ![frts.PNG](attachment:frts.PNG)

# %% [markdown]
# ###  if we consider the above table here in column 4 and column 5 the values are totally different from the othe values in the data set also the coulmn  5 having really large numbers in it,
#
# ### so when we make a train and test set to create a machine learning model it will be very hard and mostly impossible to relate each values with one another, so it is a very good idea to scale them down to simple values.
#
# ### here, in machine learning standardisation means making the values scale down into between -3 and +3 values and normalisation means making them in between 0 and 1
# ### here, we can use standardisation technique on every kind of dataset it simply makes the values float between -3 and +3 but to perform the normalisation the other features values also has to considered because it has low range of floating values

# %% [markdown]
# ![ft%20form.PNG](attachment:ft%20form.PNG)

# %% [markdown]
# ### the above formula helps to make the feature scaling

# %%
from sklearn.preprocessing import StandardScaler
# standardization of dependent variables
scaled_data = scale.fit_transform(X_data) 
print(scaled_data)

## code for nomalisation

from sklearn.preprocessing import minmax_scaler
scaling = minmax_scaler()
scaling.fit_transform(datapoints)

# %% [markdown]
# ###### the code can be explained more briefly in machine learning metireal
