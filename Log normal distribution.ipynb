# %% [markdown]
# #### The Log normal distribution is almost similar to gaussian distribution, where the incline of the curve will extends contiuesly, which is called skewnes.
#
# #### if the curve contiues at right it called right skewness vice versa

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### by using the log methods and process, log normal distribution is converted to standard normal distribution for the better accuracy of values.
