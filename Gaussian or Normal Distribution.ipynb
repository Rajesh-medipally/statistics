# %% [markdown]
# #### Gaussian distribution (also known as normal distribution) is a bell-shaped curve, and it is assumed that during any measurement values will follow a normal distribution with an equal number of measurements above and below the mean value.

# %% [markdown]
# #### it includes mean and varience

# %% [markdown]
# the average of the total is known as mean
#
#  variance measures how far each number in the set is from the mean and thus from every other number in the set.

# %% [markdown]
# ![varience%20formula.PNG](attachment:varience%20formula.PNG)

# %%
# %%HTML
# <a href="https://www.statisticshowto.com/wp-content/uploads/2013/09/Variance_Formula.png"> varience formula</a>
# Out:
# <a href="https://www.statisticshowto.com/wp-content/uploads/2013/09/Variance_Formula.png"> varience formula</a>

# %% [markdown]
# #### mean and varience are basically calculated to know the standard deviation, where, standard deviation is the distence between each quarter of the data distribution.

# %% [markdown]
# ### gaussian or normal distribution is basically a curve line shaped like a mountain

# %%
# %%HTML
# <a href="https://sphweb.bumc.bu.edu/otlt/MPH-Modules/PH717-QuantCore/PH717-Module6-RandomError/Normal%20Distribution%20deviations.png">
# gaussian curve</a>
# Out:
# <a href="https://sphweb.bumc.bu.edu/otlt/MPH-Modules/PH717-QuantCore/PH717-Module6-RandomError/Normal%20Distribution%20deviations.png">
# gaussian curve</a>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### the above curve explains about gaussian distribution.
# ### as per the gaussian  bell curve, the center point is mean and the other lines will be distributin points denoted by sigma.
#
# ### it shows, how much distribution falls into  each categories , like  first distribution 68.2% for secound 95.4% for third 99.7% the fourth quarter fills overall of 100%
#
# it basically explains in how many standard deviations how much distribution is falling using emperical formula
