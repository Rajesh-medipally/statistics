# %% [markdown]
# #### in Pearson corelation coefficiant, it works accuratly, when the data is distributed linearly
# #### to correct this error, SRCC is introduced.

# %% [markdown]
# ### basically, SRCC is also works as same as PCC, but the main difference is, it is calculated on the basis of the rank of the x and y.

# %% [markdown]
# #### in PCC, we use the formula as covarience divided with standard deviation of x and y.
# #### here in SRCC also uses the same formula but with ranks, it means, coavrience of ranks of x and y divides standard deviation fo ranks of x and y.

# %% [markdown]
# ## with an example we can understand the ranks basically means

# %% [markdown]
# ![SRCC%20example%20table.PNG](attachment:SRCC%20example%20table.PNG)

# %% [markdown]
# #### the above table shows the iq of person according to watching tv in hours, by using this we try to understand the PRCC

# %% [markdown]
# #### as the first step we needed put the values in ascending order, so the ranking can be get easier

# %% [markdown]
# ![SRCC%20ex%20ascen.PNG](attachment:SRCC%20ex%20ascen.PNG)

# %% [markdown]
# #### try to assign ranks to each value, these are less values so we can do it by our own for more use the rank function in excel. it makes easy.
#
# #### =RANK(A1,A1:A5,0) // descending, returns 5
# #### =RANK(A1,A1:A5,1) // ascending, returns 1

# %% [markdown]
# ![SRCC%20%20ex%20rank.PNG](attachment:SRCC%20%20ex%20rank.PNG)

# %% [markdown]
# ### in next step, try to find the difference between the ranks

# %% [markdown]
# ![SRCC%20ex%20diff.PNG](attachment:SRCC%20ex%20diff.PNG)

# %% [markdown]
# ## to calculate value we use the formula as

# %% [markdown]
# ![SRCC%20form.PNG](attachment:SRCC%20form.PNG)

# %% [markdown]
# #### by calculating the d square we can get the summation value and n is the rank range here it is 10

# %% [markdown]
# ![SRCC%20table.PNG](attachment:SRCC%20table.PNG)

# %% [markdown]
# #### after calculation we get value as -0.17, which is almost near to zero, so by this we can say the relation between iq and watching tv is almost zero, means very low level realtion

# %% [markdown]
# ![tv%20ex.PNG](attachment:tv%20ex.PNG)

# %% [markdown]
# ## here are some chart cases, where SRCC, PCC values differ

# %% [markdown]
# ![ex1.PNG](attachment:ex1.PNG)

# %% [markdown]
# ![ex%202.PNG](attachment:ex%202.PNG)

# %% [markdown]
# ![ex%203.PNG](attachment:ex%203.PNG)
