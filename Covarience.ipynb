# %% [markdown]
# ## covariance is a measure of the relationship between two random variables.

# %% [markdown]
# ###  the general formula for covarience explains the +ve or -ve percentage of the value, it explains the direction of the variables

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### if the x and y increases it will be +ve covariance , if x is increasing and y is decreasing ( either one in opposite direction) is -ve covariance.

# %% [markdown]
# ### here, the covarience measures can tell, is it positive or negative but it can not explain the exactness or how much it is +ve or -ve.
#
# ### to know that we use pearsons corelation coeffeciant.
